# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Load a CSV file named "data.csv" into a Pandas DataFrame.
# 2. Display the first 5 rows of the DataFrame.
# 3. Display the column names and data types in the DataFrame.
# 4. Show the summary statistics (mean, median, min, max, etc.) for
# numerical columns.

# %%
df = pd.read_csv("D:\RouteMLCourse\Online Shopping Dataset.csv")
df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0         1/1/2019
# 1     17850.0      M  Chicago           12.0         16680.0         1/1/2019
# 2     17850.0      M  Chicago           12.0         16696.0         1/1/2019
# 3     17850.0      M  Chicago           12.0         16699.0         1/1/2019
# 4     17850.0      M  Chicago           12.0         16700.0         1/1/2019
#
#       Product_SKU                                Product_Description  \
# 0  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2  GGOENEBQ078999             Nest Cam Outdoor Security Camera - USA
# 3  GGOENEBQ079099    Nest Protect Smoke + CO White Battery Alarm-USA
# 4  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
#
#   Product_Category  Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST  \
# 0         Nest-USA       1.0     153.71               6.5          Used  0.1
# 1         Nest-USA       1.0     153.71               6.5          Used  0.1
# 2         Nest-USA       2.0     122.77               6.5      Not Used  0.1
# 3         Nest-USA       1.0      81.50               6.5       Clicked  0.1
# 4         Nest-USA       1.0     153.71               6.5       Clicked  0.1
#
#        Date  Offline_Spend  Online_Spend  Month Coupon_Code  Discount_pct
# 0  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 1  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 2  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 3  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 4  1/1/2019         4500.0        2424.5      1      ELEC10          10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  float64
#  1   Gender               52924 non-null  object
#  2   Location             52924 non-null  object
#  3   Tenure_Months        52924 non-null  float64
#  4   Transaction_ID       52924 non-null  float64
#  5   Transaction_Date     52924 non-null  object
#  6   Product_SKU          52924 non-null  object
#  7   Product_Description  52924 non-null  object
#  8   Product_Category     52955 non-null  object
#  9   Quantity             52924 non-null  float64
#  10  Avg_Price            52924 non-null  float64
#  11  Delivery_Charges     52924 non-null  float64
#  12  Coupon_Status        52924 non-null  object
#  13  GST                  52924 non-null  float64
#  14  Date                 52924 non-null  object
#  15  Offline_Spend        52924 non-null  float64
#  16  Online_Spend         52924 non-null  float64
#  17  Month                52955 non-null  int64
#  18  Coupon_Code          52555 non-null  object
#  19  Discount_pct         52555 non-null  float64
# dtypes: float64(10), int64(1), object(9)
# memory usage: 8.1+ MB

# %%
df.describe()
# Out:
#         CustomerID  Tenure_Months  Transaction_ID      Quantity     Avg_Price  \
# count  52924.00000   52924.000000    52924.000000  52924.000000  52924.000000
# mean   15346.70981      26.127995    32409.825675      4.497638     52.237646
# std     1766.55602      13.478285     8648.668977     20.104711     64.006882
# min    12346.00000       2.000000    16679.000000      1.000000      0.390000
# 25%    13869.00000      15.000000    25384.000000      1.000000      5.700000
# 50%    15311.00000      27.000000    32625.500000      1.000000     16.990000
# 75%    16996.25000      37.000000    39126.250000      2.000000    102.130000
# max    18283.00000      50.000000    48497.000000    900.000000    355.740000
#
#        Delivery_Charges           GST  Offline_Spend  Online_Spend  \
# count      52924.000000  52924.000000   52924.000000  52924.000000
# mean          10.517630      0.137462    2830.914141   1893.109119
# std           19.475613      0.045825     936.154247    807.014092
# min            0.000000      0.050000     500.000000    320.250000
# 25%            6.000000      0.100000    2500.000000   1252.630000
# 50%            6.000000      0.180000    3000.000000   1837.870000
# 75%            6.500000      0.180000    3500.000000   2425.350000
# max          521.360000      0.180000    5000.000000   4556.930000
#
#               Month  Discount_pct
# count  52955.000000  52555.000000
# mean       6.652800     19.953382
# std        3.333664      8.127108
# min        1.000000     10.000000
# 25%        4.000000     10.000000
# 50%        7.000000     20.000000
# 75%        9.000000     30.000000
# max       12.000000     30.000000

# %% [markdown]
# Task 2:
# 1. Add a new column 'Total' that contains the sum of two existing
# numerical columns.
# 2. Filter the DataFrame to show rows where a specific column value
# meets a certain condition (e.g., where Avg_Price > 120).
# 3. Sort the DataFrame based on a particular column in ascending order.

# %%
df["Total"] = df["Offline_Spend"] + df["Online_Spend"]
df
# Out:
#        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# 2             1/1/2019  GGOENEBQ078999
# 3             1/1/2019  GGOENEBQ079099
# 4             1/1/2019  GGOENEBJ079499
# ...                ...             ...
# 52950              NaN             NaN
# 52951              NaN             NaN
# 52952              NaN             NaN
# 52953              NaN             NaN
# 52954              NaN             NaN
#
#                                      Product_Description  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2                 Nest Cam Outdoor Security Camera - USA
# 3        Nest Protect Smoke + CO White Battery Alarm-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# ...                                                  ...
# 52950                                                NaN
# 52951                                                NaN
# 52952                                                NaN
# 52953                                                NaN
# 52954                                                NaN
#
#            Product_Category  Quantity  ...  Delivery_Charges  Coupon_Status  \
# 0                  Nest-USA       1.0  ...               6.5           Used
# 1                  Nest-USA       1.0  ...               6.5           Used
# 2                  Nest-USA       2.0  ...               6.5       Not Used
# 3                  Nest-USA       1.0  ...               6.5        Clicked
# 4                  Nest-USA       1.0  ...               6.5        Clicked
# ...                     ...       ...  ...               ...            ...
# 52950            Gift Cards       NaN  ...               NaN            NaN
# 52951  Notebooks & Journals       NaN  ...               NaN            NaN
# 52952               Android       NaN  ...               NaN            NaN
# 52953               Android       NaN  ...               NaN            NaN
# 52954               Android       NaN  ...               NaN            NaN
#
#        GST      Date Offline_Spend  Online_Spend  Month  Coupon_Code  \
# 0      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 1      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 2      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 3      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 4      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# ...    ...       ...           ...           ...    ...          ...
# 52950  NaN       NaN           NaN           NaN     11         GC20
# 52951  NaN       NaN           NaN           NaN     11         NJ20
# 52952  NaN       NaN           NaN           NaN     10        AND10
# 52953  NaN       NaN           NaN           NaN     11        AND20
# 52954  NaN       NaN           NaN           NaN     12        AND30
#
#       Discount_pct   Total
# 0             10.0  6924.5
# 1             10.0  6924.5
# 2             10.0  6924.5
# 3             10.0  6924.5
# 4             10.0  6924.5
# ...            ...     ...
# 52950         20.0     NaN
# 52951         20.0     NaN
# 52952         10.0     NaN
# 52953         20.0     NaN
# 52954         30.0     NaN
#
# [52955 rows x 21 columns]

# %%
Avg_Price=df[df["Avg_Price"]>120]
Avg_Price
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M     Chicago           12.0         16679.0
# 1         17850.0      M     Chicago           12.0         16680.0
# 2         17850.0      M     Chicago           12.0         16696.0
# 4         17850.0      M     Chicago           12.0         16700.0
# 5         17850.0      M     Chicago           12.0         16701.0
# ...           ...    ...         ...            ...             ...
# 52739     14224.0      F     Chicago            3.0         40225.0
# 52740     14224.0      F     Chicago            3.0         40233.0
# 52862     12748.0      F     Chicago           28.0         26585.0
# 52863     12748.0      F     Chicago           28.0         26586.0
# 52919     13155.0      F  California            8.0         22504.0
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# 2             1/1/2019  GGOENEBQ078999
# 4             1/1/2019  GGOENEBJ079499
# 5             1/1/2019  GGOENEBJ079499
# ...                ...             ...
# 52739        10/9/2019  GGOEGGCX056399
# 52740        10/9/2019  GGOEGGCX056399
# 52862        4/27/2019  GGOEGGCX056399
# 52863        4/27/2019  GGOEGGCX056399
# 52919        3/10/2019  GGOEGGCX056399
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2                 Nest Cam Outdoor Security Camera - USA         Nest-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 5      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...                                                  ...              ...
# 52739                                Gift Card - $250.00       Gift Cards
# 52740                                Gift Card - $250.00       Gift Cards
# 52862                                Gift Card - $250.00       Gift Cards
# 52863                                Gift Card - $250.00       Gift Cards
# 52919                                Gift Card - $250.00       Gift Cards
#
#        Quantity  ...  Delivery_Charges  Coupon_Status   GST       Date  \
# 0           1.0  ...               6.5           Used  0.10   1/1/2019
# 1           1.0  ...               6.5           Used  0.10   1/1/2019
# 2           2.0  ...               6.5       Not Used  0.10   1/1/2019
# 4           1.0  ...               6.5        Clicked  0.10   1/1/2019
# 5           1.0  ...               6.5        Clicked  0.10   1/1/2019
# ...         ...  ...               ...            ...   ...        ...
# 52739       1.0  ...               0.0           Used  0.05  10/9/2019
# 52740       1.0  ...               0.0        Clicked  0.05  10/9/2019
# 52862       1.0  ...               0.0        Clicked  0.05  4/27/2019
# 52863       1.0  ...               0.0           Used  0.05  4/27/2019
# 52919       1.0  ...               0.0        Clicked  0.05  3/10/2019
#
#       Offline_Spend  Online_Spend  Month  Coupon_Code Discount_pct    Total
# 0            4500.0       2424.50      1       ELEC10         10.0  6924.50
# 1            4500.0       2424.50      1       ELEC10         10.0  6924.50
# 2            4500.0       2424.50      1       ELEC10         10.0  6924.50
# 4            4500.0       2424.50      1       ELEC10         10.0  6924.50
# 5            4500.0       2424.50      1       ELEC10         10.0  6924.50
# ...             ...           ...    ...          ...          ...      ...
# 52739        3500.0        734.31     10         GC10         10.0  4234.31
# 52740        3500.0        734.31     10         GC10         10.0  4234.31
# 52862        3500.0       2056.17      4         GC10         10.0  5556.17
# 52863        3500.0       2056.17      4         GC10         10.0  5556.17
# 52919        2500.0       1294.22      3         GC30         30.0  3794.22
#
# [8006 rows x 21 columns]

# %%
sort_df = df.sort_values(by="Avg_Price", ascending=True)
sort_df.head()
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 5883      12836.0      M     Chicago            6.0         45818.0
# 28623     17180.0      F     Chicago           35.0         43558.0
# 49371     13168.0      F     Chicago           24.0         41774.0
# 28399     12826.0      M  California           33.0         42923.0
# 28389     13707.0      F     Chicago           28.0         43949.0
#
#       Transaction_Date     Product_SKU    Product_Description  \
# 5883         12/6/2019  GGOEYFKQ020699  YouTube Custom Decals
# 28623       11/16/2019  GGOEYFKQ020699  YouTube Custom Decals
# 49371       10/26/2019  GGOEYFKQ020699  YouTube Custom Decals
# 28399        11/8/2019  GGOEYFKQ020699  YouTube Custom Decals
# 28389       11/20/2019  GGOEYFKQ020699  YouTube Custom Decals
#
#       Product_Category  Quantity  ...  Delivery_Charges  Coupon_Status  GST  \
# 5883            Office      31.0  ...             73.92       Not Used  0.1
# 28623           Office      15.0  ...              6.00       Not Used  0.1
# 49371           Office      10.0  ...             12.91           Used  0.1
# 28399           Office     100.0  ...              6.00           Used  0.1
# 28389           Office      20.0  ...              6.50           Used  0.1
#
#              Date Offline_Spend  Online_Spend  Month  Coupon_Code  \
# 5883    12/6/2019        3500.0       1957.58     12        OFF30
# 28623  11/16/2019        4000.0       2716.48     11        OFF20
# 49371  10/26/2019        3500.0       2374.99     10        OFF10
# 28399   11/8/2019        3500.0       2087.49     11        OFF20
# 28389  11/20/2019        2500.0       1893.03     11        OFF20
#
#       Discount_pct    Total
# 5883          30.0  5457.58
# 28623         20.0  6716.48
# 49371         10.0  5874.99
# 28399         20.0  5587.49
# 28389         20.0  4393.03
#
# [5 rows x 21 columns]

# %% [markdown]
# Task 3:
# 1. Calculate the average value of a specific column.
# 2. Find the most frequent value in a categorical column.
# 3. Group the data by a categorical column and calculate the mean for
# each group.

# %%
df["Quantity"].mean()
# Out:
# 4.497638122590885

# %%
df["Quantity"].mode()
# Out:
# 0    1.0
# Name: Quantity, dtype: float64

# %%
grouped = df.groupby("Gender")[["Offline_Spend", "Online_Spend"]].mean()
grouped
# Out:
#         Offline_Spend  Online_Spend
# Gender
# F         2862.259521   1899.806601
# M         2778.967716   1882.009868

# %% [markdown]
# Task 4:
# 1. Create a histogram to visualize the distribution of a numerical column.
# 2. Generate a bar chart to represent the frequency of categories in a
# categorical column.

# %%
import matplotlib.pyplot as plt
plt.hist(df["Avg_Price"], bins=20, edgecolor="black")
plt.title("Distribution of Avg_Price")
plt.xlabel("Avg_Price")
plt.ylabel("Frequency")
plt.show()

# %%
df["Location"].value_counts().plot(kind="bar")

plt.title("Frequency of Locations")
plt.xlabel("Location")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Task 5:
# 1. Perform data imputation to handle missing values in the DataFrame.

# %%
df.isnull().sum()
# Out:
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Online_Spend            31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# Total                   31
# dtype: int64

# %%
df["Avg_Price"].fillna(df["Avg_Price"].mean(), inplace=True)
df["Location"].fillna(df["Location"].mode()[0], inplace=True)
print(df)
# Out:
#        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN  Chicago            NaN             NaN
# 52951         NaN    NaN  Chicago            NaN             NaN
# 52952         NaN    NaN  Chicago            NaN             NaN
# 52953         NaN    NaN  Chicago            NaN             NaN
# 52954         NaN    NaN  Chicago            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# 2             1/1/2019  GGOENEBQ078999
# 3             1/1/2019  GGOENEBQ079099
# 4             1/1/2019  GGOENEBJ079499
# ...                ...             ...
# 52950              NaN             NaN
# 52951              NaN             NaN
# 52952              NaN             NaN
# 52953              NaN             NaN
# 52954              NaN             NaN
#
#                                      Product_Description  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2                 Nest Cam Outdoor Security Camera - USA
# 3        Nest Protect Smoke + CO White Battery Alarm-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# ...                                                  ...
# 52950                                                NaN
# 52951                                                NaN
# 52952                                                NaN
# 52953                                                NaN
# 52954                                                NaN
#
#            Product_Category  Quantity  ...  Delivery_Charges  Coupon_Status  \
# 0                  Nest-USA       1.0  ...               6.5           Used
# 1                  Nest-USA       1.0  ...               6.5           Used
# 2                  Nest-USA       2.0  ...               6.5       Not Used
# 3                  Nest-USA       1.0  ...               6.5        Clicked
# 4                  Nest-USA       1.0  ...               6.5        Clicked
# ...                     ...       ...  ...               ...            ...
# 52950            Gift Cards       NaN  ...               NaN            NaN
# 52951  Notebooks & Journals       NaN  ...               NaN            NaN
# 52952               Android       NaN  ...               NaN            NaN
# 52953               Android       NaN  ...               NaN            NaN
# 52954               Android       NaN  ...               NaN            NaN
#
#        GST      Date Offline_Spend  Online_Spend  Month  Coupon_Code  \
# 0      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 1      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 2      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 3      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# 4      0.1  1/1/2019        4500.0        2424.5      1       ELEC10
# ...    ...       ...           ...           ...    ...          ...
# 52950  NaN       NaN           NaN           NaN     11         GC20
# 52951  NaN       NaN           NaN           NaN     11         NJ20
# 52952  NaN       NaN           NaN           NaN     10        AND10
# 52953  NaN       NaN           NaN           NaN     11        AND20
# 52954  NaN       NaN           NaN           NaN     12        AND30
#
#       Discount_pct   Total
# 0             10.0  6924.5
# 1             10.0  6924.5
# 2             10.0  6924.5
# 3             10.0  6924.5
# 4             10.0  6924.5
# ...            ...     ...
# 52950         20.0     NaN
# 52951         20.0     NaN
# 52952         10.0     NaN
# 52953         20.0     NaN
# 52954         30.0     NaN
#
# [52955 rows x 21 columns]

# %%
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):  
        df[col] = df[col].fillna(df[col].mean())
    elif df[col].dtype == 'Object':  
        df[col] = df[col].fillna(df[col].mode()[0])  
    else: 
        df[col] = df[col].fillna(df[col].mode()[0])

print(df)
# Out:
#         CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0      17850.00000      M  Chicago      12.000000    16679.000000
# 1      17850.00000      M  Chicago      12.000000    16680.000000
# 2      17850.00000      M  Chicago      12.000000    16696.000000
# 3      17850.00000      M  Chicago      12.000000    16699.000000
# 4      17850.00000      M  Chicago      12.000000    16700.000000
# ...            ...    ...      ...            ...             ...
# 52950  15346.70981      F  Chicago      26.127995    32409.825675
# 52951  15346.70981      F  Chicago      26.127995    32409.825675
# 52952  15346.70981      F  Chicago      26.127995    32409.825675
# 52953  15346.70981      F  Chicago      26.127995    32409.825675
# 52954  15346.70981      F  Chicago      26.127995    32409.825675
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# 2             1/1/2019  GGOENEBQ078999
# 3             1/1/2019  GGOENEBQ079099
# 4             1/1/2019  GGOENEBJ079499
# ...                ...             ...
# 52950       11/27/2019  GGOENEBJ079499
# 52951       11/27/2019  GGOENEBJ079499
# 52952       11/27/2019  GGOENEBJ079499
# 52953       11/27/2019  GGOENEBJ079499
# 52954       11/27/2019  GGOENEBJ079499
#
#                                      Product_Description  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2                 Nest Cam Outdoor Security Camera - USA
# 3        Nest Protect Smoke + CO White Battery Alarm-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# ...                                                  ...
# 52950  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 52951  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 52952  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 52953  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 52954  Nest Learning Thermostat 3rd Gen-USA - Stainle...
#
#            Product_Category  Quantity  ...  Delivery_Charges  Coupon_Status  \
# 0                  Nest-USA  1.000000  ...           6.50000           Used
# 1                  Nest-USA  1.000000  ...           6.50000           Used
# 2                  Nest-USA  2.000000  ...           6.50000       Not Used
# 3                  Nest-USA  1.000000  ...           6.50000        Clicked
# 4                  Nest-USA  1.000000  ...           6.50000        Clicked
# ...                     ...       ...  ...               ...            ...
# 52950            Gift Cards  4.497638  ...          10.51763        Clicked
# 52951  Notebooks & Journals  4.497638  ...          10.51763        Clicked
# 52952               Android  4.497638  ...          10.51763        Clicked
# 52953               Android  4.497638  ...          10.51763        Clicked
# 52954               Android  4.497638  ...          10.51763        Clicked
#
#             GST        Date Offline_Spend  Online_Spend  Month  Coupon_Code  \
# 0      0.100000    1/1/2019   4500.000000   2424.500000      1       ELEC10
# 1      0.100000    1/1/2019   4500.000000   2424.500000      1       ELEC10
# 2      0.100000    1/1/2019   4500.000000   2424.500000      1       ELEC10
# 3      0.100000    1/1/2019   4500.000000   2424.500000      1       ELEC10
# 4      0.100000    1/1/2019   4500.000000   2424.500000      1       ELEC10
# ...         ...         ...           ...           ...    ...          ...
# 52950  0.137462  11/27/2019   2830.914141   1893.109119     11         GC20
# 52951  0.137462  11/27/2019   2830.914141   1893.109119     11         NJ20
# 52952  0.137462  11/27/2019   2830.914141   1893.109119     10        AND10
# 52953  0.137462  11/27/2019   2830.914141   1893.109119     11        AND20
# 52954  0.137462  11/27/2019   2830.914141   1893.109119     12        AND30
#
#       Discount_pct       Total
# 0             10.0  6924.50000
# 1             10.0  6924.50000
# 2             10.0  6924.50000
# 3             10.0  6924.50000
# 4             10.0  6924.50000
# ...            ...         ...
# 52950         20.0  4724.02326
# 52951         20.0  4724.02326
# 52952         10.0  4724.02326
# 52953         20.0  4724.02326
# 52954         30.0  4724.02326
#
# [52955 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID             0
# Gender                 0
# Location               0
# Tenure_Months          0
# Transaction_ID         0
# Transaction_Date       0
# Product_SKU            0
# Product_Description    0
# Product_Category       0
# Quantity               0
# Avg_Price              0
# Delivery_Charges       0
# Coupon_Status          0
# GST                    0
# Date                   0
# Offline_Spend          0
# Online_Spend           0
# Month                  0
# Coupon_Code            0
# Discount_pct           0
# Total                  0
# dtype: int64
